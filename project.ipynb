# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# %matplotlib inline

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.set()
plt.figure(figsize=(6,6)) 
sns.displot(df['age'], kde = True)
plt.xlim(0 ,80)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x= df['sex'], data = df)
plt.title("Sex distribution")
# Out:
# Text(0.5, 1.0, 'Sex distribution')

# %%
df.sex.value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(6,6))
sns.displot(df['bmi'], kde= True)
plt.title("BMI")
plt.show()

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(6,6))
sns.countplot(x= df['children'], data = df)
plt.title("Children")
plt.show()

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(6,6))
sns.countplot( x= df['smoker'])
# plt.xlabel("Smoker")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(6,6))
sns.countplot(x = df['region'])
plt.xlabel = ("Region")
plt.plot()
# Out:
# []

# %%
df.region.value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(6,6))
sns.displot(x = df['charges'])
plt.xlabel = ("Charges")
plt.show()

# %%
df['sex'] = df['sex'].replace({'male' : 0, 'female' :1})
# Out:
# C:\Users\adpub\AppData\Local\Temp\ipykernel_23296\3571062559.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['sex'] = df['sex'].replace({'male' : 0, 'female' :1})

# %%
df['sex'] = df['sex'].astype(int)

# %%
df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    1  27.900         0    yes  southwest  16884.92400
# 1   18    0  33.770         1     no  southeast   1725.55230
# 2   28    0  33.000         3     no  southeast   4449.46200
# 3   33    0  22.705         0     no  northwest  21984.47061
# 4   32    0  28.880         0     no  northwest   3866.85520

# %%
df.sex.value_counts()
# Out:
# sex
# 0    676
# 1    662
# Name: count, dtype: int64

# %%
df = df.replace({'yes' : 0, 'no' :1})
# Out:
# C:\Users\adpub\AppData\Local\Temp\ipykernel_23296\1604026457.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({'yes' : 0, 'no' :1})

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    1  27.900         0       0  southwest  16884.92400
# 1   18    0  33.770         1       1  southeast   1725.55230
# 2   28    0  33.000         3       1  southeast   4449.46200
# 3   33    0  22.705         0       1  northwest  21984.47061
# 4   32    0  28.880         0       1  northwest   3866.85520

# %%
df.smoker.value_counts()
# Out:
# smoker
# 1    1064
# 0     274
# Name: count, dtype: int64

# %%
df.region.value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df['region'] = df['region'].replace({'southeast' : 0, 'southwest': 1, 'northwest':2, 'northeast': 3})
# Out:
# C:\Users\adpub\AppData\Local\Temp\ipykernel_23296\691168903.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['region'] = df['region'].replace({'southeast' : 0, 'southwest': 1, 'northwest':2, 'northeast': 3})

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       0       1  16884.92400
# 1   18    0  33.770         1       1       0   1725.55230
# 2   28    0  33.000         3       1       0   4449.46200
# 3   33    0  22.705         0       1       2  21984.47061
# 4   32    0  28.880         0       1       2   3866.85520

# %%
df.region.value_counts()
# Out:
# region
# 0    364
# 1    325
# 2    325
# 3    324
# Name: count, dtype: int64

# %%
X = df.iloc[:, :-1]
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       2
# 4      32    0  28.880         0       1       2
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       2
# 1334   18    1  31.920         0       1       3
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       2
#
# [1338 rows x 6 columns]

# %%
Y = df.iloc[: , -1]
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null